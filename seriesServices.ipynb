# %%
import requests

# %%
import re

# %%
url = 'http://myhastidl.xyz/%D8%AF%D8%A7%D9%86%D9%84%D9%88%D8%AF-%D8%B3%D8%B1%DB%8C%D8%A7%D9%84-the-big-bang-theory-%D9%81%D8%B5%D9%84-%D8%AF%D9%87%D9%85/'

# %%
page = requests.get(url).content.decode('utf-8')

# %%
page
# Out:
# '<!DOCTYPE HTML>\n<html>\n    <head>\n        <title>دانلود سریال The Big Bang Theory فصل 12 دوازدهم - هستی دی ال</title>\n        <meta name="theme-color" content="#61e69a" />\n        <meta http-equiv="Content-Type" content="text/html" charset="utf-8" />\n        <meta http-equiv="Content-Language" content="fa">\n        <meta name="robots" content="index, follow">\n        <meta name="language" content="Farsi">\n        <meta name="viewport" content="width=device-width, initial-scale=1,maximum-scale=1,user-scalable=no">\n        <link rel="icon" type="image/x-icon" href="" />\n        <meta name="keywords" content="">\n        <meta name="description" content="">\n        \n<!-- This site is optimized with the Yoast SEO Premium plugin v9.6.1 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="دانلود سریال The Big Bang Theory فصل یازدهم \xa0دانلود \xa0سریال\xa0The Big Bang Theory 2015 با کیفیت عالی\xa0سریال The Big Bang Theory با لینک مستقیم"/>\n<link 
# ...

# %%
page = 'https://www.imdb.com/title/tt0898266/episodes?season=12&ref_=tt_eps_sn_12'

# %%
re.findall("http(?!.*http).*[sS]12.*[eE]10(?!.*http).*mkv", page)
# Out:
# ['http://dl.myhastidl.xyz/data/the.big.bang.theory.s12e10.480p.hdtv.x264.rmteam.mkv']

# %%
re.findall("(?<=_)[0-9]+$", page)
# Out:
# ['12']

# %%
re.findall(r"http[^\ ]*[sS]12[^\ ]*[eE]10[^\ ]*mkv", page)
# Out:
# ['http://dl.myhastidl.xyz/data/The.Big.Bang.Theory.S12E10.720p.HDTV.x264.Hastidl.mkv',
#  'http://dl.myhastidl.xyz/data/the.big.bang.theory.s12e10.720p.hdtv.hevc.x265.rmteam.mkv',
#  'http://dl.myhastidl.xyz/data/the.big.bang.theory.s12e10.480p.hdtv.x264.rmteam.mkv']

# %%
re.findall(r"http((?!http).)*[sS]12((?!http).)*[eE]10((?!http).)*mkv", page)
# Out:
# [('.', '', '.'), ('.', '', '.'), ('.', '', '.')]
